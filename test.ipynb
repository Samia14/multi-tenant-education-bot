# %%
import json
from phi.model.openai import OpenAIChat

# %%
with open(r"C:\Users\mysel\Downloads\doctors_enriched_embedding_ready.json", encoding="utf-8") as f:
    data = json.load(f)

# %%
from phi.embedder.openai import OpenAIEmbedder

# %%
from phi.knowledge.json import JSONKnowledgeBase
from phi.vectordb.pgvector import PgVector

knowledge_base = JSONKnowledgeBase(
    path="C:\\Users\\mysel\\Downloads\\doctors_enriched_embedding_ready.json",
    # Table name: ai.json_documents
    vector_db=PgVector(
        table_name="json_documents",
        db_url="postgresql+psycopg://postgres:HelloWorld1!@4.240.100.54:5432/postgres",embedder=OpenAIEmbedder(api_key=os.getenv("OPENAI_API_KEY"),model='text-embedding-3-large')
    ),
)

# %%
import os

# %%
from phi.agent import Agent
os.environ["OPENAI_API_KEY"]='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'
agent = Agent(model=
       OpenAIChat(id='gpt-4o-mini',api_key=os.getenv("OPENAI_API_KEY"),temperature=0.3),
    knowledge=knowledge_base,
    search_knowledge=True,
)
agent.knowledge.load(recreate=True)

agent.print_response("Ask me about something from the knowledge base")
# Out:
# INFO     Dropping collection
# INFO     Table 'ai.json_documents' dropped successfully.
# INFO     Creating collection
# INFO     Loading knowledge base
# INFO     Reading: C:\Users\mysel\Downloads\doctors_enriched_embedding_ready.json
# ERROR    Error processing document 'doctors_enriched_embedding_ready': Request timed out.
# ERROR    Error processing document 'doctors_enriched_embedding_ready': Connection error.
# ERROR    Error processing document 'doctors_enriched_embedding_ready': Connection error.
# ERROR    Error processing document 'doctors_enriched_embedding_ready': Connection error.
# ERROR    Error processing document 'doctors_enriched_embedding_ready': Connection error.
# ERROR    Error processing document 'doctors_enriched_embedding_ready': Connection error.
# ERROR    Error processing document 'doctors_enriched_embedding_ready': Connection error.
# ERROR    Error processing document 'doctors_enriched_embedding_ready': Connection error.
# ERROR    Error processing document 'doctors_enriched_embedding_ready': Connection error.
# INFO     Inserted batch of 36 documents.
# INFO     Added 45 documents to knowledge base
# c:\Users\mysel\project\EducationBot\test\Lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# !pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\mysel\project\educationbot\test\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\mysel\project\educationbot\test\lib\site-packages (from ipywidgets) (9.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\mysel\project\educationbot\test\lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: colorama in c:\users\mysel\project\educationbot\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\mysel\project\educationbot\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\mysel\project\educationbot\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\mysel\project\educationbot\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\mysel\project\educationbot\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\mysel\project\educationbot\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mysel\project\educationbot\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\mysel\project\educationbot\test\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\mysel\project\educationbot\test\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\mysel\project\educationbot\test\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\mysel\project\educationbot\test\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\mysel\project\educationbot\test\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\mysel\project\educationbot\test\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 65.9 kB/s eta 0:00:26
#    --------- ------------------------------ 0.5/2.2 MB 65.9 kB/s eta 0:00:26
#    --------- ------------------------------ 0.5/2.2 MB 65.9 kB/s eta 0:00:26
#    --------- ------------------------------ 0.5/2.2 MB 65.9 kB/s eta 0:00:26
#    -------------- ------------------------- 0.8/2.2 MB 104.4 kB/s eta 0:00:14
#    -------------- ------------------------- 0.8/2.2 MB 104.4 kB/s eta 0:00:14
#    -------------- ------------------------- 0.8/2.2 MB 104.4 kB/s eta 0:00:14
#    -------------- ------------------------- 0.8/2.2 MB 104.4 kB/s eta 0:00:14
#    -------------- ------------------------- 0.8/2.2 MB 104.4 kB/s eta 0:00:14
#    -------------- ------------------------- 0.8/2.2 MB 104.4 kB/s eta 0:00:14
#    -------------- ------------------------- 0.8/2.2 MB 104.4 kB/s eta 0:00:14
#    ------------------- -------------------- 1.0/2.2 MB 121.7 kB/s eta 0:00:10
#    ------------------- -------------------- 1.0/2.2 MB 121.7 kB/s eta 0:00:10
#    ------------------- -------------------- 1.0/2.2 MB 121.7 kB/s eta 0:00:10
#    ------------------- -------------------- 1.0/2.2 MB 121.7 kB/s eta 0:00:10
#    ------------------- -------------------- 1.0/2.2 MB 121.7 kB/s eta 0:00:10
#    ------------------- -------------------- 1.0/2.2 MB 121.7 kB/s eta 0:00:10
#    ------------------- -------------------- 1.0/2.2 MB 121.7 kB/s eta 0:00:10
#    ----------------------- ---------------- 1.3/2.2 MB 132.2 kB/s eta 0:00:07
#    ----------------------- ---------------- 1.3/2.2 MB 132.2 kB/s eta 0:00:07
#    ----------------------- ---------------- 1.3/2.2 MB 132.2 kB/s eta 0:00:07
#    ----------------------- ---------------- 1.3/2.2 MB 132.2 kB/s eta 0:00:07
#    ----------------------- ---------------- 1.3/2.2 MB 132.2 kB/s eta 0:00:07
#    ----------------------- ---------------- 1.3/2.2 MB 132.2 kB/s eta 0:00:07
#    ----------------------- ---------------- 1.3/2.2 MB 132.2 kB/s eta 0:00:07
#    ----------------------- ---------------- 1.3/2.2 MB 132.2 kB/s eta 0:00:07
#    ----------------------- ---------------- 1.3/2.2 MB 132.2 kB/s eta 0:00:07
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    ---------------------------- ----------- 1.6/2.2 MB 133.7 kB/s eta 0:00:05
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 120.1 kB/s eta 0:00:04
#    ---------------------------------------- 2.2/2.2 MB 120.1 kB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
# Successfully installed ipywidgets-8.1.7 jupyterlab_widgets-3.0.15 widgetsnbextension-4.0.14
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
agent.print_response("Ask me about something from the knowledge base")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
